# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn

# %% [markdown]
# ##   Data Analysis

# %%
movie_data= pd.read_csv("IMDB-Movie-Data.csv") #Reading the data

# %%
movie_data
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
movie_data.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
movie_data.tail()
# Out:
#      Rank                   Title                  Genre  \
# 995   996    Secret in Their Eyes    Crime,Drama,Mystery
# 996   997         Hostel: Part II                 Horror
# 997   998  Step Up 2: The Streets    Drama,Music,Romance
# 998   999            Search Party       Adventure,Comedy
# 999  1000              Nine Lives  Comedy,Family,Fantasy
#
#                                            Description          Director  \
# 995  A tight-knit team of rising investigators, alo...         Billy Ray
# 996  Three American college students studying abroa...          Eli Roth
# 997  Romantic sparks occur between two dance studen...        Jon M. Chu
# 998  A pair of friends embark on a mission to reuni...    Scot Armstrong
# 999  A stuffy businessman finds himself trapped ins...  Barry Sonnenfeld
#
#                                                 Actors  Year  \
# 995  Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...  2015
# ...

# %%
movie_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
movie_data.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# ...

# %%
movie_data.shape
# Out:
# (1000, 12)

# %%
movie_data.corr()
# Out:
#                         Rank      Year  Runtime (Minutes)    Rating     Votes  \
# Rank                1.000000 -0.261605          -0.221739 -0.219555 -0.283876
# Year               -0.261605  1.000000          -0.164900 -0.211219 -0.411904
# Runtime (Minutes)  -0.221739 -0.164900           1.000000  0.392214  0.407062
# Rating             -0.219555 -0.211219           0.392214  1.000000  0.511537
# Votes              -0.283876 -0.411904           0.407062  0.511537  1.000000
# Revenue (Millions) -0.271592 -0.126790           0.267953  0.217654  0.639661
# Metascore          -0.191869 -0.079305           0.211978  0.631897  0.325684
#
#                     Revenue (Millions)  Metascore
# Rank                         -0.271592  -0.191869
# Year                         -0.126790  -0.079305
# Runtime (Minutes)             0.267953   0.211978
# Rating                        0.217654   0.631897
# Votes                         0.639661   0.325684
# ...

# %%
movie_data.isnull()
movie_data.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %% [markdown]
# ## Data visualization

# %% [markdown]
# ## 1. Relation between Rating & Metascore

# %%
fig , ax = plt.subplots()

ax.scatter(movie_data['Rating'], movie_data['Metascore'] )

ax.set_title('relation between Rating & Metascore')
ax.set_xlabel('Rating')
ax.set_ylabel('Metascore')
plt.show()

# %% [markdown]
# Here, we notice that the metascore conforms almost perfectly to the rating; in other words, the higher the rating, the higher the metascore. This confirms the correlation between the rating and the metascore.

# %% [markdown]
# ## 2. Plots of RunTime

# %% [markdown]
# ##      2.1 Histogram of RunTime

# %%
movie_data['Runtime (Minutes)'].plot(kind='hist', bins=30)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# This histogram tells us that most of the movies have a duration of 100–120 minutes

# %% [markdown]
# ## 2.2 Box Of RunTime

# %%
movie_data['Runtime (Minutes)'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %% [markdown]
# The green line is the Median of the runtime

# %% [markdown]
# Box plot is telling us the same thing that most of the movies have a duration somewhere from 100 to 125 and we also have a clear median (=113) . Whereas, with histogram, we were unable to see the median clearly.

# %% [markdown]
# ## 2.3 The top 10 movies with the highest 'runtime' :

# %%
runtime_10_film = movie_data.loc[:, ["Runtime (Minutes)", "Title"]].iloc[movie_data["Runtime (Minutes)"].sort_values(ascending=False)[:10].index]
runtime_10_film
# Out:
#      Runtime (Minutes)                                     Title
# 828                191                                Grindhouse
# 88                 187                         The Hateful Eight
# 965                180                             Inland Empire
# 311                180                            La vie d'Adèle
# 82                 180                   The Wolf of Wall Street
# 267                172                               Cloud Atlas
# 430                170                                  3 Idiots
# 75                 169  Pirates of the Caribbean: At World's End
# 271                169         The Hobbit: An Unexpected Journey
# 36                 169                              Interstellar

# %%
plt.figure(figsize=(5,5))
sns.barplot(x= "Title", y= "Runtime (Minutes)", data=runtime_10_film)
plt.title("10 Movies with Highest Runtime Value")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# As we have seen in the top 10 movie visualizations with the highest RunTime value
#
#     The first three
#
#      *Grindhouse
#      *The Hateful Eight
#      *Inland Empire
#
#     Last Three
#
#      *Pirates of the Caribbean: At World's End
#      *The Hobbit: An Unexpected Journey
#      *Interstellar

# %% [markdown]
# ## 3. The most popular Genres

# %%
#count how many movies have each Genre
movies_genres=movie_data[['Title','Genre']].groupby('Genre').count() 
# show the first 20 genres 
movies_genres=movies_genres.sort_values(by=['Title'],ascending=False).head(20)

movies_genres.plot(kind='bar')
plt.xlabel('Genre')
plt.ylabel('Genre Count')
plt.title('The most popular Genres')
movies_genres
# Out:
#                             Title
# Genre
# Action,Adventure,Sci-Fi        50
# Drama                          48
# Comedy,Drama,Romance           35
# Comedy                         32
# Drama,Romance                  31
# Action,Adventure,Fantasy       27
# Comedy,Drama                   27
# Animation,Adventure,Comedy     27
# Comedy,Romance                 26
# Crime,Drama,Thriller           24
# Crime,Drama,Mystery            23
# Action,Adventure,Drama         18
# Action,Crime,Drama             17
# Horror,Thriller                16
# Drama,Thriller                 15
# Biography,Drama                14
# Action,Adventure,Comedy        14
# Adventure,Family,Fantasy       14
# Biography,Drama,History        14
# Action,Comedy,Crime            12

# %% [markdown]
# This plot displays the most frequent genres of movies across our data set,It appears that movies of the ‘Action, adventure , sci-fi’ genres are the most released .

# %% [markdown]
# ## 4. Revenue By Years :

# %%
df_aggregated = movie_data.groupby(movie_data['Year']).agg({'Revenue (Millions)': ['sum']})
df_aggregated
# Out:
#      Revenue (Millions)
#                     sum
# Year
# 2006            3624.46
# 2007            4306.23
# 2008            5053.22
# 2009            5292.26
# 2010            5989.65
# 2011            5431.96
# 2012            6910.29
# 2013            7666.72
# 2014            7997.40
# 2015            8854.12
# 2016           11211.65

# %%
import seaborn as sns

# %%
sns.lineplot(data=df_aggregated, x='Year', y=df_aggregated['Revenue (Millions)']['sum'], color='#8dbb69')
plt.ylabel('Revenue (Millions)')
plt.title('Revenue By Years')
plt.show()

# %% [markdown]
# From 2008 to 2010, we notice a continuous increase in revenue, then it decreases slightly between 2010 and 2011, and then it returns to the highest value in 2016.

# %% [markdown]
# ## 5 . Relation between Runtime & Rating:

# %%
#count how many movies have each Genre
movies_rating=movie_data.sort_values(by=['Rating'],ascending=False)




movies_rating
# Out:
#      Rank                    Title                     Genre  \
# 54     55          The Dark Knight        Action,Crime,Drama
# 80     81                Inception   Action,Adventure,Sci-Fi
# 117   118                   Dangal    Action,Biography,Drama
# 36     37             Interstellar    Adventure,Drama,Sci-Fi
# 96     97            Kimi no na wa   Animation,Drama,Fantasy
# ..    ...                      ...                       ...
# 968   969                  Wrecker    Action,Horror,Thriller
# 647   648                 Tall Men   Fantasy,Horror,Thriller
# 871   872     Dragonball Evolution  Action,Adventure,Fantasy
# 42     43  Don't Fuck in the Woods                    Horror
# 829   830           Disaster Movie                    Comedy
#
#                                            Description           Director  \
# 54   When the menace known as the Joker wreaks havo...  Christopher Nolan
# 80   A thief, who steals corporate secrets through ...  Christopher Nolan
# ...

# %%
sns.lineplot(data=movies_rating, x='Runtime (Minutes)', y=movies_rating['Rating'], color='#000')
plt.ylabel('Rating')
plt.xlabel('Runtime (Minutes)')

plt.title('Relation between Runtime & Rating')
plt.show()

# %% [markdown]
# Movies that are between 150 and 165 minutes long tend to get the highest rating
